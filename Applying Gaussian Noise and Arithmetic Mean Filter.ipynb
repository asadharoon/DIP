# %% [markdown]
# Note: I am Using Scipy v1.1.0. In case of any errors you can install scipy 1.1.0 by the following command:
# pip install scipy==1.1.0

# %%
import scipy
scipy.__version__
# Out:
# '1.1.0'

# %% [markdown]
# To download images Click on this url: https://drive.google.com/drive/folders/1pcaTwofZGfoCxZ3Hv2X6vW6xf_1i88eb?usp=sharing

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.misc import imread
import math
from skimage.util import random_noise
from skimage.filters import rank
from scipy import ndimage

# %% [markdown]
# # Original Image

# %%
original_image=imread("circuit_image.png",False,'L')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.

# %%
plt.imshow(original_image,plt.cm.gray)

# %%
processed_image=original_image.copy()

# %% [markdown]
# # Adding Gaussian Noise

# %%
noise_img = random_noise(processed_image, mode='gaussian')
noise_image=noise_img*255

# %%
plt.imshow(noise_image,plt.cm.gray)

# %%
hist=plt.hist(noise_image.flatten(),bins=256,range=[0,255])

# %% [markdown]
# # Applying Arithmetic Mean Filter

# %%
kernel_arithmetic_mean = 1/9*np.ones((3,3))
img=ndimage.convolve(noise_image, kernel_arithmetic_mean, mode='constant', cval=0.0)
plt.imshow(img,plt.cm.gray)
